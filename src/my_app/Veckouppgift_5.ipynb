# %% [raw]
# 1 Vilka ekvivalensklasser har uttrycken?

# %% [markdown]
# 1a.  x > 100
#
# klass 1) x > 100    Större än 100 "TRUE"
# klass 2) x < 100    Mindre eller lika med 100 "FALSE"
#
# Gränsvärdesanalys: Värdena runt 100 till exempel 99,100,101

# %% [markdown]
# 1b. y == 42
#
# klass 1) y < 42     Y är mindre än 42   "FALSE"
# Klass 2) y > 42     Y är större än 42   "FALSE"
# klass 3) Y == 42    Y är lika med 42    "TRUE"
#
# Gränsvärdesanalys: Värdena runt 42 till exempel 41,42,43

# %% [markdown]
# 1c. len(text) >= 5
#
# Klass 1) len(text) >= 5      texter som är längre än 5 tecken "TRUE"
# Klass 2) len(text) >= 5      texter som är mellan 0 och 5 tecken "FALSE"

# %% [markdown]
#  1d. z == True
#
# Klass 1)    z == True       Om z är True       "TRUE"
# Klass 2)    z == False      om z är false       "FALSE"

# %% [markdown]
# 1e. 8 < v < 16
#
# Klass 1)  8 < v  v är mindre eller lika med än 8 "FALSE"
# Klass 2)  v < 16 v är större eller lika med 16 "FALSE"
# Klass 3)  v  är mellan 8 och 16

# %% [markdown]
# 1f. w == 32 or w == 64 or w == 128
#
# 1) W är lika med 32, 64, 128    "TRUE"
# 2) w är ej lika med 32, 64, 120     "FALSE"
